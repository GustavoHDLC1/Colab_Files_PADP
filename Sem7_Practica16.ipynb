# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoHDLC1/Colab_Files_PADP/blob/main/Sem7_Practica16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctica 16: Datos Duplicados
# [Enlace GitHub](https://github.com/GustavoHDLC1/Colab_Files_PADP/blob/main/Sem7_Practica16.ipynb)

# %%
import pandas as pd

# %% [markdown]
# ## Ejercicio 01. Datos Perdidos.

# %%
# Carga el conjunto de datos dirty.csv y verifica que su carga sea correcta.
df = pd.read_csv('/content/drive/MyDrive/MIAAD/PADP/dirtydata.csv')
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
# Imprime la cantidad de datos perdidos que tiene el conjunto de datos
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
# Calcula la media de la columna Calories
mean_cal = df['Calories'].mean()
print(mean_cal)
# Out:
# 304.68

# %%
# Aplica imputación por promedio (mean) en la columna Calories
df["Calories"] = df["Calories"].fillna(mean_cal)
df[['Calories']].isnull().sum()
# Out:
# Calories    0
# dtype: int64

# %%
# Calcula de nuevo la media de la columna Calories después de que has imputado.
mean_cal2 = df['Calories'].mean()
print(mean_cal2)
# Out:
# 304.67999999999995

# %% [markdown]
# ## Ejercicio 02. Duplicidad Parcial Una columna: Contar y Filtrar los registros duplicados en Duration

# %%
# Carga el conjunto de datos dirty.csv y verifica que su carga sea correcta.
df = pd.read_csv('/content/drive/MyDrive/MIAAD/PADP/dirtydata.csv')
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
# Cuenta la cantidad de registros duplicados utilizando solo la información de columna Duration e imprime
dup_dur = df.duplicated(subset=['Duration'], keep='first').sum()
print(dup_dur)
# Out:
# 28

# %%
# Utiliza value_counts() e imprime la cantidad de registros que hay por cada valor único.
df['Duration'].value_counts()
# Out:
# Duration
# 60     24
# 45      6
# 450     1
# 30      1
# Name: count, dtype: int64

# %%
# Filtra los datos y obten los registros sin duplicados
df[~df.duplicated(subset=['Duration'], keep=False)]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 7       450  '2020/12/08'    104       134     253.3
# 8        30  '2020/12/09'    109       133     195.1

# %% [markdown]
# ## Ejercicio 03 Duplicidad Parcial Dos columnaa: Contar y Filtrar los registros duplicados en Pulse y MaxPulse

# %%
# Carga el conjunto de datos dirty.csv y verifica que su carga sea correcta.
df = pd.read_csv('/content/drive/MyDrive/MIAAD/PADP/dirtydata.csv')
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
# Cuenta la cantidad de registros duplicados utilizando la información de las columnas Pulse y Maxpulse
dup_pul = df.duplicated(subset=['Pulse', 'Maxpulse'], keep='first').sum()
print(dup_pul)
# Out:
# 3

# %%
# Utiliza value_counts() e imprime la cantidad de registros que hay por cada valor único.
df[['Pulse','Maxpulse']].value_counts()
# Out:
# Pulse  Maxpulse
# 100    120         4
# 92     115         1
#        118         1
# 97     125         1
# 90     112         1
# 98     120         1
#        123         1
#        124         1
# 100    119         1
#        132         1
# 102    126         1
#        127         1
#        129         1
# 103    123         1
#        132         1
#        135         1
#        147         1
# 104    132         1
#        134         1
# 105    132         1
# 106    128         1
# 108    131         1
# 109    133         1
#        175         1
# 110    130         1
#        136         1
# 117    145         1
#        148         1
# 130    101         1
# Name: count, dtype: int64

# %%
# Filtra los datos y obten los registros cuando keep = 'last'
df[df.duplicated(subset=['Pulse','Maxpulse'], keep='last')]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 17        60  '2020/12/17'    100       120     300.0

# %% [markdown]
# ## Ejercicio 04 Duplicidad Total o Exacta: Contar y Filtrar los registros duplicados

# %%
# Carga el conjunto de datos dirty.csv y verifica que su carga sea correcta.
df = pd.read_csv('/content/drive/MyDrive/MIAAD/PADP/dirtydata.csv')
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
# Cuenta la cantidad de registros duplicados exactos (todas las columnas)
dup = df.duplicated(subset=None, keep='first').sum()
print(dup)
# Out:
# 1

# %%
# Utiliza sum() e imprime la cantidad de registros con duplicidad exacta
print(df.duplicated(subset=None, keep='first').sum())
# Out:
# 1

# %%
# Filtra los datos y obten los registros cuando keep = 'last'
df[df.duplicated(subset=None, keep='last')]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 11        60  '2020/12/12'    100       120     250.7

# %% [markdown]
# ## Ejercicio 05: Cálculo de la media con duplicados y sin duplicados

# %%
# Carga el conjunto de datos dirty.csv y verifica que su carga sea correcta.
df = pd.read_csv('/content/drive/MyDrive/MIAAD/PADP/dirtydata.csv')
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
# Calcula e imprime la media de las columnas Pulse y MaxPulse
mean_pul = df['Pulse'].mean()
mean_max = df['Maxpulse'].mean()
print(mean_pul)
print(mean_max)
# Out:
# 103.5
# 128.5

# %%
# Identifica los valores duplicados en las columnas Pulse y MaxPulse (Duplicidad Parcial) y elimina los registro repetidos. Quédate con las últimas ocurrencias
df = df[~df.duplicated(subset=['Pulse', 'Maxpulse'], keep='last')]

# %%
# Utiliza el conjunto anterior sin datos duplicados (recuerda que solo quedaron las últimas ocurrencias de los datos) y calcula la media de las columnas Pulse y MaxPulse
mean_pul2 = df['Pulse'].mean()
mean_max2 = df['Maxpulse'].mean()
print(mean_pul2)
print(mean_max2)
# Out:
# 103.86206896551724
# 129.3793103448276
