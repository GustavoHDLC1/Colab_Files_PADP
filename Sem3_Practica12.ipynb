# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoHDLC1/Colab_Files_PADP/blob/main/Sem3_Practica12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Enlace GitHub](https://github.com/GustavoHDLC1/Colab_Files_PADP/blob/main/Sem3_Practica12.ipynb)

# %%
import seaborn as sns
import plotly.graph_objects as go

# %%
# 1.- Cargar el dataset "flights" del paquete seaborn
df = sns.load_dataset("flights")
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
# 2.- Transforma los datos: Organizar los datos para crear un mapa de calor. Reorganizalos para que los años estén en filas y los meses en columnas.
data_mapa = df.pivot(index="year", columns="month", values="passengers")
data_mapa
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
# 3.- Crear el mapa de calor: Usa el código para crear un mapa de calor con plotly.
# 4.- Personalizar el gráfico: Cambia el título, los colores o agregar otras etiquetas para hacer el gráfico más claro.
fig = go.Figure(
    data=go.Heatmap(
        z=data_mapa.values, x=data_mapa.columns, y=data_mapa.index, colorscale="Ice", colorbar=dict(title="Pasajeros")
    )
)
fig.update_layout(
    title="Número de pasajeros por mes y año",
    xaxis_title="Mes",
    yaxis_title="Año",
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
